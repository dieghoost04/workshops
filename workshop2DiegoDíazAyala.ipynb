# %% [markdown]
# # Workshop 2
#
# ## Diego Díaz Ayala
#
# ## A01770236

# %%
from symbulate import *
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# clear the plot space:
plt.clf()
# Define the probability type of function as uniform (probability space)
P = Uniform(0,40)
# Define X as a random variable of the type P (uniform)
X =RV(P)
# Simulate the values of X and save the in the x array: 
x=X.sim(10000)
x.plot()
plt.show()

# %% [markdown]
# The variance is calculated as the mean of the squared differences between each value and the mean. Since all values ​​within the interval [a,b] are equally likely, we can use the midpoint as the most representative value:
#
#
# $$
# \overline{x} = \frac{(a+b)}{2}\\
# Var(x) = \int(x-\overline{x})^{2}*f(x) dx
# $$

# %% [markdown]
# $$Var(x) = \frac{(b-a)^2}{12}$$

# %% [markdown]
# ### 2.2.2 CHALLENGE

# %% [markdown]
# A. WE CALCULATE DE VARIANCE TO GET THE THOERICAL STANDARD DEVIATION AND THE NORMAL STANDARD DEVIATION, AND WE CAN SEE THAT THE VALUES ARE REALLY CLOSE TO EACH OTHER.
#
# B. THE HISTOGRAM ABOVE ES THE REPRESENTATION OF UNIFORM DISTRIBUTION.

# %%
var = (40*40)/12
print(var)
print(x.sd()*x.sd())

sd = sqrt(var)
print(sd)
print(x.sd())
# Out:
# 133.33333333333334
# 132.68955550638597
# 11.547005383792516
# 11.519095255547892

# %%
# Define the probability space as a vector of 25 uniform random numbers:
P = Uniform(0,40) ** 25
# Define XVECTOR as a vector of random variables with 25 random values 
XVECTOR =RV(P)
# Simulate 10,000 vectors to get a matrix  
xmatrix=XVECTOR.sim(10000)

# %%
xmatrix
# Out:
# Index Result
# 0     (30.730847519455395, 13.206594252725935, 10.847062711879744, 8.870953067785745, 37.79972018805064, ..., 21.890141929903074)
# 1     (21.110005869417847, 12.988822558386172, 23.93233307155643, 32.54855066815132, 39.90679573389678, ..., 7.763516987963701)
# 2     (36.66472382441755, 28.828776697959793, 4.188133646540861, 36.90965989375319, 10.46561089128097, ..., 25.90073677512259)
# 3     (11.225279405312772, 7.915075280545234, 33.247715881660305, 24.773277340465476, 1.1080866242992515, ..., 13.400652745120883)
# 4     (16.285208844378047, 33.93841073833291, 1.807219090587564, 1.98382129290128, 2.0204750493976853, ..., 3.8983687661949995)
# 5     (28.144228138326902, 18.779079495209018, 25.175844661598124, 15.859071022616922, 28.75858052551456, ..., 30.863942444596457)
# 6     (21.329138119939483, 16.311852225700136, 23.695918718778675, 6.072261152448739, 4.620299930024263, ..., 35.22375270894574)
# ...

# %%
# The 2nd parameter is the mathematical operation applied to each row of the random vector
# Simulate 10,000 means of each random vector of 25 uniform distributed numbers: 
xmean = RV(P,mean).sim(10000)
xmean
# Out:
# Index Result
# 0     19.26667412698684
# 1     20.844591608677014
# 2     17.206640355777186
# 3     14.735976276033993
# 4     18.539838244306036
# 5     20.578145502282922
# 6     16.388128978243685
# 7     16.913372486068106
# 8     20.187386264084935
# ....  ..................
# 9999  22.217850689569744

# %%
plt.clf()
xmean.plot()
plt.show()

# %% [markdown]
# ### 2.2.3 CHALLENGE

# %% [markdown]
# A. IN THE CELL BELOW WE CALCULATE DE SD AND MEAN OF XMEAN AND WE CAN SEE THAT BOTH VALUES ARE VERY DIFFERENT FROM X VALUES.
#
# B. THIS HISTOGRAM REPRESENTS THE MEAN OF UNIFORM DISTRIBUTION, AND A WAY TO EXPLAIN THIS BEHAVIOUR IS THAT THE GREATER VALUES OF THE UNIFORM DISTRIBUTION ARE CANCELED WITH THE LOWER VALUES, AND THE VALUES THAT APPEAR IN THE HALF ARE THE ONES WHO HAD A HIGHER PROBABILITY OF APPEAR.

# %%
print(xmean.mean())
print(xmean.sd())
# Out:
# 19.990826948491723
# 2.30508199671615

# %%
plt.clf()
xmean.plot()
x.plot()
plt.show()

# %%
# clear the plot space:
plt.clf()
# Define the probability type of function as uniform (probability space)
P = Normal(mean=20, sd=10)
# Define Y as a random variable of the type P (normal)
Y =RV(P)
# Simulate 10,000 values of Y and save the in the x array: 
y=Y.sim(10000)
y.plot()
plt.show()

# %% [markdown]
# ### 2.2.5 CHALLENGE

# %% [markdown]
# A. WE CAN SEE THAT IN THIS CASE THE VALUE OF THE VARIANCE IS NOT THAT CLOSE TO THE THEORICAL ONE.

# %%
var = (60-20)**2/12
print(var)
print(y.sd()*y.sd())

sd = sqrt(var)
print(sd)
print(y.sd())
print(y.mean())
# Out:
# 133.33333333333334
# 100.95493563350456
# 11.547005383792516
# 10.047633334945328
# 20.191899552392197

# %%
# Define the probability space P as a vector of 25 normal random numbers:
P = Normal(mean=20, sd=10) ** 25
# Define RANDOMVECTOR as a vector of 25 random variables in the Probability space P 
RANDOMVECTOR = RV(P)
# Simulate 10,000 random vectors with this distribution and save the in ymatrix: 
ymatrix=RANDOMVECTOR.sim(10000)

# %%
ymatrix
# Out:
# Index Result
# 0     (11.898064108689173, 16.05045089894817, 27.95437548041472, 0.28520556771915295, 27.204921307123584, ..., 26.02164228933421)
# 1     (4.9137119983620625, 33.63261802817459, 27.504042585237443, 28.80012954568399, 24.403765629451062, ..., 22.96172654692049)
# 2     (-8.171742709428717, 24.817296358974218, 18.8085128077606, 10.709925050251822, 28.64235219978361, ..., 19.961872339529695)
# 3     (26.65574532035996, 21.150225166148015, 23.13364851484897, 11.693861877313529, 8.477754179044833, ..., 30.77338629853032)
# 4     (27.23388083017683, 12.062840991190487, 23.031556460871144, 21.12868407502719, 32.30584739847444, ..., 0.7806822195625642)
# 5     (12.48061177985656, 17.224611971948715, 27.72292170720142, 7.279730307817079, 4.638729481018089, ..., 28.969227529306437)
# 6     (23.742048548811496, 24.235476908334334, 11.604274613332986, 21.243166764455832, 30.79051111467633, ..., 30.75410789203076)
# ...

# %%
# The 2nd parameter is the mathematical operation applied to each row of the random vector
# Simulate 10,000 means of each random vector of 25 uniform distributed numbers: 
ymean = RV(P,mean).sim(10000)
ymean
# Out:
# Index Result
# 0     19.9655406223642
# 1     16.719169252103168
# 2     22.960221734845437
# 3     19.38476424726246
# 4     22.521465330468136
# 5     20.052707216094337
# 6     19.858333247258344
# 7     19.687468332779005
# 8     18.776371209719002
# ....  ................
# 9999  20.1488250315145

# %%
plt.clf()
ymean.plot()
plt.show()

# %% [markdown]
# ### 2.2.6 CHALLENGE

# %% [markdown]
# A. WE CAN SEE THAT THE VALUES ARE PRETTY SIMILAR.
#
# B. THIS HISTOGRAM SHOWS 10000 GENERATED MEANS OF SAMPLES OF Y, AND WE CAN SEE HOW THIS MEANS ARE DISTRIBUTED ON THE HISTOGRAM.

# %%
print(ymean.sd())
print(ymean.mean())
# Out:
# 1.9912400973932458
# 19.986900057137962

# %%
plt.clf()
ymean.plot()
y.plot()
plt.show()

# %% [markdown]
# C. THE CENTRAL LIMIT TEOREM TELLS US THAT WHEN WE GET THE MEANS OF RANDOM VALUES, THE DISTRIBUTION OF THEM WILL BE CLOSE TO NORMAL DISTRIBUTION.

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# ### 4.1 CHALLENGE

# %%
MSFT=yf.download(tickers="MSFT", start="2017-01-01",interval="1mo")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close
# Date
# 2017-01-01   62.790001   65.910004   61.950001   64.650002   59.148552  \
# 2017-02-01   64.360001   65.239998   62.750000   63.980000   58.535557
# 2017-03-01   64.129997   66.190002   63.619999   65.860001   60.620895
# 2017-04-01   65.809998   69.139999   64.849998   68.459999   63.014042
# 2017-05-01   68.680000   70.739998   67.139999   69.839996   64.284264
# ...                ...         ...         ...         ...         ...
# 2023-04-01  286.519989  308.929993  275.369995  307.260010  305.942047
# 2023-05-01  306.970001  335.940002  303.399994  328.390015  326.981384
# 2023-06-01  325.929993  351.470001  322.500000  340.540009  339.820526
# 2023-07-01  339.190002  366.779999  327.000000  335.920013  335.210297
# 2023-08-01  335.190002  338.540009  311.549988  322.459991  322.459991
#
#                Volume
# Date
# ...

# %% [markdown]
# B. THE NULL HYPOTHESIS: THE MEAN OF MSFT IS EQUAL TO 0
#    THE ALTERNATIVE HYPOTHESIS: THE MEAN OF MSFT IS GREATER THA 0

# %%
# CALCULATE THE STANDARD ERROR, WHICH IS THE STANDARD DEVIATION OF THE VARIABLE OF SrTUDY.
returns = MSFT['Adj Close'].tolist()
std_d = np.std(returns)
n = len(returns)
std_d = std_d / np.sqrt(n)
print(std_d)
# Out:
# 9.873782400375118

# %%
# CALCULATE THE t-statistic (t-value). EXPLAIN/INTERPRET THE t-statistic
s_mean = np.mean(returns)
null = 0  
t_v = (sample_mean) / std_d

# %%
# CONFIDENCE INTERVAL 95%
A = 0.05
t_c = np.abs(np.percentile(returns, A * 100 / 2))
confidence_interval = (s_mean - t_c * std_d, s_mean + t_c * std_d)

# %%
if t_v > t_c:
    conclusion = "Podemos rechazar la hipótesis nula ya que hay evidencia suficiente para demostrar que la media es igual a cero."
else:
    conclusion = "No podemos rechazar la hipotesis nula ya que no hay evidencia suficiente para demostrar que la media es mayor que cero."

print("Conclusion:", conclusion)
# Out:
# Conclusion: No podemos rechazar la hipotesis nula ya que no hay evidencia suficiente para demostrar que la media es mayor que cero.
