# %% [markdown]
# # Workshop 1
#
# ## Diego Díaz Ayala
#
# ## A01770236

# %%
from symbulate import *
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# clear the plot space:
plt.clf()
# Define the probability type of function as uniform (probability space)
P = Uniform(0,40)
# Define X as a random variable of the type P (uniform)
X =RV(P)
# Simulate the values of X and save the in the x array: 
x=X.sim(10000)
x.plot()
plt.show()

# %% [markdown]
# La varianza se calcula como la media de las diferencias al cuadrado entre cada valor y la media. Dado que todos los valores dentro del intervalo [a,b] son igualmente probalbes podemos usar el punto medio como el valor mas representativo:
#
# $$
# \overline{x} = \frac{(a+b)}{2}\\
# Var(x) = \int(x-\overline{x})^{2}*f(x) dx
# $$

# %% [markdown]
# $$Var(x) = \frac{(b-a)^2}{12}$$

# %%
var = (40*40)/12
print(var)

sd = sqrt(var)
print(sd)

print(x.sd()*x.sd())
print(x.sd())
# Out:
# 133.33333333333334
# 11.547005383792516
# 133.01262032455696
# 11.533109742153544

# %%
# Define the probability space as a vector of 25 uniform random numbers:
P = Uniform(0,40) ** 25
# Define XVECTOR as a vector of random variables with 25 random values 
XVECTOR =RV(P)
# Simulate 10,000 vectors to get a matrix  
xmatrix=XVECTOR.sim(10000)

# %%
xmatrix
# Out:
# Index Result
# 0     (33.282406731310246, 25.487955028352264, 28.455586604207625, 21.170768998401396, 31.400566564825212, ..., 17.795913368375942)
# 1     (19.452033357423172, 38.19160851898586, 35.59270357273099, 36.68361860704913, 1.9397073808176701, ..., 4.352812311179055)
# 2     (3.4607770656954306, 13.149195844245796, 1.0318486570851704, 0.05051686036606107, 3.4628378217426237, ..., 19.520015960962954)
# 3     (4.811898912840911, 6.787692161892229, 23.163821927894904, 35.801476751178164, 25.080482512783195, ..., 24.158749726041123)
# 4     (0.283138038321491, 21.740284080505482, 16.83583949757239, 29.043048107987318, 31.38405190094168, ..., 9.893644348882269)
# 5     (18.9943255796172, 13.39211126154758, 11.9174786903677, 26.66615795664444, 4.330348916480111, ..., 2.8823328625238664)
# 6     (13.944927960315287, 1.7864057684219636, 6.615166375259722, 7.998567178230269, 36.17490515963638, ..., 27.24069830584269)
# ...

# %%
# The 2nd parameter is the mathematical operation applied to each row of the random vector
# Simulate 10,000 means of each random vector of 25 uniform distributed numbers: 
xmean = RV(P,mean).sim(10000)
xmean
# Out:
# Index Result
# 0     18.78433719365108
# 1     18.218002072433205
# 2     25.20352330954634
# 3     17.367653061094924
# 4     19.388997387923343
# 5     17.53318797436152
# 6     18.867852916664265
# 7     16.230191700260868
# 8     18.396624660197695
# ....  ..................
# 9999  16.993707966240287

# %%
plt.clf()
xmean.plot()
plt.show()

# %%
print(xmean.mean())
print(xmean.sd())
# Out:
# 20.041316190064233
# 2.2738070403080157

# %%
plt.clf()
xmean.plot()
x.plot()
plt.show()

# %%
# clear the plot space:
plt.clf()
# Define the probability type of function as uniform (probability space)
P = Normal(mean=20, sd=10)
# Define Y as a random variable of the type P (normal)
Y =RV(P)
# Simulate 10,000 values of Y and save the in the x array: 
y=Y.sim(10000)
y.plot()
plt.show()

# %%
# Define the probability space P as a vector of 25 normal random numbers:
P = Normal(mean=20, sd=10) ** 25
# Define RANDOMVECTOR as a vector of 25 random variables in the Probability space P 
RANDOMVECTOR = RV(P)
# Simulate 10,000 random vectors with this distribution and save the in ymatrix: 
ymatrix=RANDOMVECTOR.sim(10000)

# %%
ymatrix
# Out:
# Index Result
# 0     (15.204991278494509, 9.446120438549679, 16.423586254360405, 33.851002970920845, 7.951508469990227, ..., 23.491484268311787)
# 1     (1.9561185920842377, 30.30915205505821, 19.128837535680734, 23.558530796440216, 26.016083209605746, ..., 22.572993746562425)
# 2     (0.6050545688474713, 16.572974052722067, 13.075641758459723, 18.46064143742517, 27.155044598325823, ..., 2.783515076658748)
# 3     (12.662531881616655, 43.92366772738053, 10.0863241636114, 9.314116159927856, 24.874032146263374, ..., 5.537574168676599)
# 4     (33.92089095041237, 32.289804359940405, 38.16821411841423, 33.22166445112324, 6.623255899380133, ..., 31.169425133930112)
# 5     (24.708914783114444, 26.906600025673725, 23.12920737591126, 34.56163691323344, 28.66013730618245, ..., 10.153346469658144)
# 6     (10.390451768624903, -0.2640155914819502, 9.2660628541754, 14.249683675354321, 10.582985698617597, ..., 27.613232967948264)
# ...

# %%
# The 2nd parameter is the mathematical operation applied to each row of the random vector
# Simulate 10,000 means of each random vector of 25 uniform distributed numbers: 
ymean = RV(P,mean).sim(10000)
ymean
# Out:
# Index Result
# 0     18.935742699546807
# 1     19.532443239335063
# 2     21.082428653324218
# 3     17.72915134908589
# 4     19.567810794483247
# 5     21.84069148010516
# 6     18.319666019869377
# 7     23.390626967066964
# 8     17.14476485942348
# ....  ..................
# 9999  18.706082077465442

# %%
plt.clf()
ymean.plot()
plt.show()

# %%
plt.clf()
ymean.plot()
y.plot()
plt.show()
